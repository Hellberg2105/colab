# %% [markdown]
# <a href="https://colab.research.google.com/github/Hellberg2105/colab/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !unzip "/content/drive/MyDrive/data/spermdatatrackedtrain.zip" -d "/content"
# Out:
# Archive:  /content/drive/MyDrive/data/spermdatatrackedtrain.zip
#    creating: /content/spermdatatrackedtrain/
#    creating: /content/spermdatatrackedtrain/test/
#    creating: /content/spermdatatrackedtrain/test/healthy/
#   inflating: /content/spermdatatrackedtrain/test/healthy/16.avi
#   inflating: /content/spermdatatrackedtrain/test/healthy/7.avi
#    creating: /content/spermdatatrackedtrain/test/unhealthy/
#   inflating: /content/spermdatatrackedtrain/test/unhealthy/2.avi
#   inflating: /content/spermdatatrackedtrain/test/unhealthy/24.avi
#    creating: /content/spermdatatrackedtrain/train/
#    creating: /content/spermdatatrackedtrain/train/healthy/
#   inflating: /content/spermdatatrackedtrain/train/healthy/1.avi
#   inflating: /content/spermdatatrackedtrain/train/healthy/10.avi
#   inflating: /content/spermdatatrackedtrain/train/healthy/11.avi
#   inflating: /content/spermdatatrackedtrain/train/healthy/12.avi
# ...

# %%
import cv2
import math
import matplotlib.pyplot as plt
from PIL import Image
import numpy as np
import os
import keras

nframes = 40

def data_load_function(directory):
    dataset = []
    labels = []
    nframes = 40
    n=1
    for (subdir, dirs, files)in os.walk(directory):
        print(subdir)
        n=1
        frames = []
        for file in files:
            # cap = cv2.VideoCapture(subdir+"/"+file)

            # Define the dimensions of the frames
            frame_width = 224
            frame_height = 224
            
            # Define an empty list to store the frames
    
                
            path_to_file = os.path.join(subdir,file)
            
            frame = cv2.imread(path_to_file)
            
            # Resize the frame to the desired dimensions
            frame = cv2.resize(frame, (frame_width, frame_height))
            frame = np.array(frame)
            # Convert the frame to an array and append it to the list
            #if (n % 2) != 0:
            frames.append(np.array(frame))
            
            # Convert the list of frames to a numpy array
            

            
            # Print the shape of the array
            if n == nframes:               
                frames = np.array(frames)
                dataset.append(frames)
                frames = []
                if "unhealthy" in subdir:
                  labels.append(1)
                else:
                  labels.append(0)
                n=0
                
            n+=1
    print(np.array(dataset).shape)
    return np.array(dataset), np.array(labels)

test_dataset, test_labels = data_load_function("/content/celldata/test")



train_dataset, train_labels = data_load_function("/content/celldata/train")



np.save("/content/drive/MyDrive/data/numpyarr/test_dataset.npy",test_dataset)
np.save("/content/drive/MyDrive/data/numpyarr/test_labels.npy",test_labels)
np.save("/content/drive/MyDrive/data/numpyarr/train_dataset.npy",train_dataset)
np.save("/content/drive/MyDrive/data/numpyarr/train_labels.npy",train_labels)
print(test_dataset.shape)
print(train_dataset.shape)
# Out:
# /content/celldata/test
# /content/celldata/test/healthy
# /content/celldata/test/healthy/9-Pos002_002
# /content/celldata/test/healthy/9-Pos002_002/reconstructed
# /content/celldata/test/healthy/Pos4
# /content/celldata/test/healthy/Pos4/reconstructed
# /content/celldata/test/healthy/9-Pos004_001
# /content/celldata/test/healthy/9-Pos004_001/reconstructed
# /content/celldata/test/healthy/9-Pos000_002
# /content/celldata/test/healthy/9-Pos000_002/reconstructed
# /content/celldata/test/healthy/Pos16
# /content/celldata/test/healthy/Pos16/reconstructed
# /content/celldata/test/healthy/9-Pos001_004
# /content/celldata/test/healthy/9-Pos001_004/reconstructed
# /content/celldata/test/healthy/Pos6
# /content/celldata/test/healthy/Pos6/reconstructed
# /content/celldata/test/healthy/Pos10
# /content/celldata/test/healthy/Pos10/reconstructed
# /content/celldata/test/healthy/Pos8
# /content/celldata/test/healthy/Pos8/reconstructed
# /content/celldata/test/unhealthy
# ...

# %%
test_dataset_new = np.load("/content/drive/MyDrive/data/numpyarr/test_dataset.npy")
test_labels = np.load("/content/drive/MyDrive/data/numpyarr/test_labels.npy")
train_dataset_new = np.load("/content/drive/MyDrive/data/numpyarr/train_dataset.npy")
train_labels = np.load("/content/drive/MyDrive/data/numpyarr/train_labels.npy")
print(train_dataset_new.shape)
print(len(train_labels))
print(test_dataset_new.shape)
print(len(test_labels))
# Out:
# (78, 59, 224, 224, 3)
# 78
# (14, 59, 224, 224, 3)
# 14

# %%
pip install remotezip tqdm opencv-python==4.5.2.52 opencv-python-headless==4.5.2.52 tf-models-official
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.0/51.0 MB 26.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 38.2/38.2 MB 33.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.6/2.6 MB 86.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.0/6.0 MB 99.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 240.6/240.6 kB 26.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 591.0/591.0 kB 51.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.6/43.6 kB 5.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 630.1/630.1 kB 49.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 66.4 MB/s eta 0:00:00
# ...

# %%
import tqdm
import random
import pathlib
import itertools
import collections

import cv2
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt

import keras
import tensorflow as tf
import tensorflow_hub as hub
from tensorflow.keras import layers
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import SparseCategoricalCrossentropy

# %%
model_id = 'a0'
resolution = 224

tf.keras.backend.clear_session()

backbone = movinet.Movinet(model_id=model_id)
backbone.trainable = False

# Set num_classes=600 to load the pre-trained weights from the original model
model = movinet_model.MovinetClassifier(backbone=backbone, num_classes=600)
model.build([None, None, None, None, 3])

# Load pre-trained weights
# !wget https://storage.googleapis.com/tf_model_garden/vision/movinet/movinet_a0_base.tar.gz -O movinet_a0_base.tar.gz -q
# !tar -xvf movinet_a0_base.tar.gz

checkpoint_dir = f'movinet_{model_id}_base'
checkpoint_path = tf.train.latest_checkpoint(checkpoint_dir)
checkpoint = tf.train.Checkpoint(model=model)
status = checkpoint.restore(checkpoint_path)
status.assert_existing_objects_matched()


def build_classifier(batch_size, num_frames, resolution, backbone, num_classes):
  """Builds a classifier on top of a backbone model."""
  model = movinet_model.MovinetClassifier(
      backbone=backbone,
      num_classes=num_classes)
  model.build([batch_size, num_frames, resolution, resolution, 3])

  return model

  num_epochs = 2

loss_obj = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True)

optimizer = tf.keras.optimizers.Adam(learning_rate = 0.001)

model.compile(loss=loss_obj, optimizer=optimizer, metrics=['accuracy'])

results = model.fit(train_dataset_new, train_labels,
                    validation_data=(test_dataset_new,test_labels),
                    epochs=10,
                    validation_freq=1,
                    verbose=1)

model.evaluate((test_dataset_new,test_labels), return_dict=True)
# Out:
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# ...

# %%
import cv2
import math
import matplotlib.pyplot as plt

import numpy as np
import os
import keras

test_dataset_new = np.load("test_dataset.npy")
test_labels = np.load("test_labels.npy")
train_dataset_new = np.load("train_dataset.npy")
train_labels = np.load("train_labels.npy")


nframes = 30


ntrainhealthy = np.count_nonzero(train_labels==0)
ntrainunhealthy = np.count_nonzero(train_labels==1)
ntesthealthy = np.count_nonzero(test_labels==0)
ntestunhealthy = np.count_nonzero(test_labels==1)



test_dataset_new=test_dataset_new.reshape((len(test_labels),nframes,250,250,3))
train_dataset_new=train_dataset_new.reshape((len(train_labels),nframes,250,250,3))

from keras.layers import TimeDistributed, Conv2D, Dense, MaxPooling2D, Flatten, LSTM, Dropout, BatchNormalization,GlobalAveragePooling2D
from keras import models

from transformers import VideoMAEImageProcessor, VideoMAEForVideoClassification
import tensorflow as tf
import tensorflow_hub as hub

encoder = hub.KerasLayer(hub_url, trainable=True)

inputs = tf.keras.layers.Input(
    shape=[None, None, None, 3],
    dtype=tf.float32,
    name='image')

# [batch_size, 600]
outputs = encoder(dict(image=inputs))

model = tf.keras.Model(inputs, outputs, name='movinet')



callbacks_list_cnlst=[keras.callbacks.EarlyStopping(
monitor='acc',patience=3),
               keras.callbacks.ModelCheckpoint(
               filepath='cnn_lstm_model_new4.h5',
               monitor='val_loss',
               save_best_only=True),
                keras.callbacks.ReduceLROnPlateau(monitor = "val_loss", factor = 0.1, patience = 3)
               ]

from keras import optimizers
optimizer_new=optimizers.RMSprop(learning_rate=0.01)
model_cnlst.compile(optimizer="adam",loss='binary_crossentropy',metrics=['acc'])

history=model_cnlst.fit(train_dataset_new,train_labels,batch_size=1,epochs=50,
                        validation_data=(test_dataset_new,test_labels),
                       callbacks=callbacks_list_cnlst)

# %%
# !pip install -q git+https://github.com/tensorflow/docs
# Out:
#   Preparing metadata (setup.py) ... done

# %%
from tensorflow_docs.vis import embed
from tensorflow import keras
from imutils import paths

import matplotlib.pyplot as plt
import tensorflow as tf
import pandas as pd
import numpy as np
import imageio
import cv2
import os

# %%
def countsamples(path):

    nframes = 10
    count = 0
    for (subdir, dirs, files)in os.walk(path):
        #print(subdir)
        n=1
        
        for file in files:
            # cap = cv2.VideoCapture(subdir+"/"+file)
            cap = cv2.VideoCapture(subdir+"/"+file)
            while True:
                ret, frame = cap.read()
                if not ret:
                   break
            # Convert the list of frames to a numpy array
            

            
            # Print the shape of the array
                if n == nframes:               
                    count+=1
                    n=0
                
                n+=1
    return count
print(countsamples("/content/spermdatatrackedtrain/train"))
print(countsamples("/content/spermdatatrackedtrain/test"))
# Out:
# 869
# 737

# %%
IMG_SIZE = 200
BATCH_SIZE = 1
EPOCHS = 30

MAX_SEQ_LENGTH = 10
NUM_FEATURES = 2048

def crop_center_square(frame):
    y, x = frame.shape[0:2]
    min_dim = min(y, x)
    start_x = (x // 2) - (min_dim // 2)
    start_y = (y // 2) - (min_dim // 2)
    return frame[start_y : start_y + min_dim, start_x : start_x + min_dim]


def load_video(path, max_frames=0, resize=(IMG_SIZE, IMG_SIZE)):
    dataset = []
    labels = []
    nframes = max_frames
    n=1
    for (subdir, dirs, files)in os.walk(path):
        print(subdir)
        n=1
        frames = []
        for file in files:
            cap = cv2.VideoCapture(subdir+"/"+file)
            while True:
                ret, frame = cap.read()
                if not ret:
                    break
            # Define the dimensions of the frames
                frame_width = 200
                frame_height = 200
                
                # Define an empty list to store the frames
        
                    
                #path_to_file = os.path.join(subdir,file)
                
                #frame = cv2.imread(path_to_file)
                
                # Resize the frame to the desired dimensions
                frame = cv2.resize(frame, resize)
                frame = np.array(frame)
                # Convert the frame to an array and append it to the list
                
                frames.append(np.array(frame))
                
                # Convert the list of frames to a numpy array
                

                
                # Print the shape of the array
                if n == nframes:
     
                    frames = np.array(frames)
                    dataset.append(frames)
                    frames = []
                    if "unhealthy" in subdir:
                      labels.append(1)
                    else:
                      labels.append(0)
                    n=0
                
                n+=1
    print(np.array(dataset).shape)
    return np.array(dataset), np.array(labels)

# %%
def build_feature_extractor():
    feature_extractor = keras.applications.InceptionV3(
        weights="imagenet",
        include_top=False,
        pooling="avg",
        input_shape=(IMG_SIZE, IMG_SIZE, 3),
    )
    preprocess_input = keras.applications.inception_v3.preprocess_input

    inputs = keras.Input((IMG_SIZE, IMG_SIZE, 3))
    preprocessed = preprocess_input(inputs)

    outputs = feature_extractor(preprocessed)
    return keras.Model(inputs, outputs, name="feature_extractor")


feature_extractor = build_feature_extractor()

# %%
def prepare_all_videos( root_dir,samp):
    num_samples = samp
    idx=0
    labels =np.array([])
    # `frame_masks` and `frame_features` are what we will feed to our sequence model.
    # `frame_masks` will contain a bunch of booleans denoting if a timestep is
    # masked with padding or not.
    frame_masks = np.zeros(shape=(num_samples, MAX_SEQ_LENGTH), dtype="bool")
    frame_features = np.zeros(
        shape=(num_samples, MAX_SEQ_LENGTH, NUM_FEATURES), dtype="float32"
    )

    # For each video.
    for (subdir, dirs, files)in os.walk(root_dir):
        # Gather all its frames and add a batch dimension.
        if len(files) != 0:
          print(subdir)
          frames, label = load_video(subdir,max_frames=MAX_SEQ_LENGTH)
          labels = np.append(labels,label)
          for frames in frames:
            frames = frames[None, ...]
            # Initialize placeholders to store the masks and features of the current video.
            temp_frame_mask = np.zeros(shape=(1, MAX_SEQ_LENGTH,), dtype="bool")
            temp_frame_features = np.zeros(
                shape=(1, MAX_SEQ_LENGTH, NUM_FEATURES), dtype="float32"
            )
            #print(frames.shape,labels)
            # Extract features from the frames of the current video.
            for i, batch in enumerate(frames):
                video_length = batch.shape[0]
                length = min(MAX_SEQ_LENGTH, video_length)
                for j in range(length):
                    temp_frame_features[i, j, :] = feature_extractor.predict(
                        batch[None, j, :]
                    )
                temp_frame_mask[i, :length] = 1  # 1 = not masked, 0 = masked

            frame_features[idx,] = temp_frame_features.squeeze()
            frame_masks[idx,] = temp_frame_mask.squeeze()
            idx+=1
    return (frame_features, frame_masks), labels


train_data, train_labels = prepare_all_videos( "/content/spermdatatrackedtrain/train",countsamples("/content/spermdatatrackedtrain/train"))
test_data, test_labels = prepare_all_videos( "/content/spermdatatrackedtrain/test",countsamples("/content/spermdatatrackedtrain/test"))

np.save("/content/drive/MyDrive/data/numpyarr/test_data20.npy",test_data[0])
np.save("/content/drive/MyDrive/data/numpyarr/test_data21.npy",test_data[1])
np.save("/content/drive/MyDrive/data/numpyarr/test_labels2.npy",test_labels)
np.save("/content/drive/MyDrive/data/numpyarr/train_data20.npy",train_data[0])
np.save("/content/drive/MyDrive/data/numpyarr/train_data21.npy",train_data[1])
np.save("/content/drive/MyDrive/data/numpyarr/train_labels2.npy",train_labels)


print(f"Frame features in train set: {train_data[0].shape}")
print(f"Frame masks in train set: {train_data[1].shape}")
# Out:
# Streaming output truncated to the last 5000 lines.
# ...
# 1/1 [==============================] - 0s 40ms/step
# ...
# ...
# 1/1 [==============================] - 0s 74ms/step
# Frame features in train set: (869, 10, 2048)
# Frame masks in train set: (869, 10)

# %%
np.save("/content/drive/MyDrive/data/numpyarr/test_data20.npy",test_data[0])
np.save("/content/drive/MyDrive/data/numpyarr/test_data21.npy",test_data[1])
np.save("/content/drive/MyDrive/data/numpyarr/test_labels2.npy",test_labels)
np.save("/content/drive/MyDrive/data/numpyarr/train_data20.npy",train_data[0])
np.save("/content/drive/MyDrive/data/numpyarr/train_data21.npy",train_data[1])
np.save("/content/drive/MyDrive/data/numpyarr/train_labels2.npy",train_labels)

print(f"Frame features in train set: {train_data[0].shape}")
print(f"Frame masks in train set: {train_data[1].shape}")
# Out:
# Frame features in train set: (869, 10, 2048)
# Frame masks in train set: (869, 10)

# %%
test_data = (np.load("/content/drive/MyDrive/data/numpyarr/test_data20.npy"),(np.load("/content/drive/MyDrive/data/numpyarr/test_data21.npy")))
test_labels = np.load("/content/drive/MyDrive/data/numpyarr/test_labels2.npy")
train_data = (np.load("/content/drive/MyDrive/data/numpyarr/train_data20.npy"),(np.load("/content/drive/MyDrive/data/numpyarr/train_data21.npy")))
train_labels = np.load("/content/drive/MyDrive/data/numpyarr/train_labels2.npy")

print(f"Frame features in train set: {train_data[0].shape}")
print(f"Frame masks in train set: {train_data[1].shape}")
# Out:
# Frame features in train set: (869, 10, 2048)
# Frame masks in train set: (869, 10)

# %%
# Utility for our sequence model.
def get_sequence_model():
 
    class_vocab=["healthy","unhealthy"]
    frame_features_input = keras.Input((MAX_SEQ_LENGTH, NUM_FEATURES))
    mask_input = keras.Input((MAX_SEQ_LENGTH,), dtype="bool")

    # Refer to the following tutorial to understand the significance of using `mask`:
    # https://keras.io/api/layers/recurrent_layers/gru/
    x = keras.layers.GRU(16, return_sequences=True)(
        frame_features_input, mask=mask_input
    )
    x = keras.layers.GRU(8)(x)
    x = keras.layers.Dropout(0.4)(x)
    x = keras.layers.Dense(8, activation="relu")(x)
    output = keras.layers.Dense(len(class_vocab), activation="softmax")(x)

    rnn_model = keras.Model([frame_features_input, mask_input], output)

    rnn_model.compile(
        loss="sparse_categorical_crossentropy", optimizer="adam", metrics=["accuracy"]
    )
    return rnn_model


# Utility for running experiments.
def run_experiment():
    filepath = "/content/video_classifier"
    checkpoint = keras.callbacks.ModelCheckpoint(
        filepath, save_weights_only=True, save_best_only=True, verbose=1
    )

    seq_model = get_sequence_model()
    history = seq_model.fit(
        [train_data[0], train_data[1]],
        train_labels,
        validation_split=0.1,
        epochs=40,
        callbacks=[checkpoint],
    )

    seq_model.load_weights(filepath)
    _, accuracy = seq_model.evaluate([test_data[0], test_data[1]], test_labels)
    print(f"Test accuracy: {round(accuracy * 100, 2)}%")

    return history, seq_model


_, sequence_model = run_experiment()
# Out:
# Epoch 1/40
# 23/25 [==========================>...] - ETA: 0s - loss: 0.7232 - accuracy: 0.5910
# Epoch 1: val_loss improved from inf to 0.71344, saving model to /content/video_classifier
# 25/25 [==============================] - 15s 120ms/step - loss: 0.7210 - accuracy: 0.5895 - val_loss: 0.7134 - val_accuracy: 0.0000e+00
# Epoch 2/40
# 25/25 [==============================] - ETA: 0s - loss: 0.6826 - accuracy: 0.6381
# Epoch 2: val_loss did not improve from 0.71344
# 25/25 [==============================] - 0s 14ms/step - loss: 0.6826 - accuracy: 0.6381 - val_loss: 0.7660 - val_accuracy: 0.0000e+00
# Epoch 3/40
# 25/25 [==============================] - ETA: 0s - loss: 0.6675 - accuracy: 0.6611
# Epoch 3: val_loss did not improve from 0.71344
# 25/25 [==============================] - 0s 14ms/step - loss: 0.6675 - accuracy: 0.6611 - val_loss: 0.8235 - val_accuracy: 0.0000e+00
# Epoch 4/40
# 23/25 [==========================>...] - ETA: 0s - loss: 0.6548 - accuracy: 0.6671
# ...

# %%
class PositionalEmbedding(layers.Layer):
    def __init__(self, sequence_length, output_dim, **kwargs):
        super().__init__(**kwargs)
        self.position_embeddings = layers.Embedding(
            input_dim=sequence_length, output_dim=output_dim
        )
        self.sequence_length = sequence_length
        self.output_dim = output_dim

    def call(self, inputs):
        # The inputs are of shape: `(batch_size, frames, num_features)`
        length = tf.shape(inputs)[1]
        positions = tf.range(start=0, limit=length, delta=1)
        embedded_positions = self.position_embeddings(positions)
        return inputs + embedded_positions

    def compute_mask(self, inputs, mask=None):
        mask = tf.reduce_any(tf.cast(inputs, "bool"), axis=-1)
        return mask

class TransformerEncoder(layers.Layer):
    def __init__(self, embed_dim, dense_dim, num_heads, **kwargs):
        super().__init__(**kwargs)
        self.embed_dim = embed_dim
        self.dense_dim = dense_dim
        self.num_heads = num_heads
        self.attention = layers.MultiHeadAttention(
            num_heads=num_heads, key_dim=embed_dim, dropout=0.3
        )
        self.dense_proj = keras.Sequential(
            [layers.Dense(dense_dim, activation=tf.nn.gelu), layers.Dense(embed_dim),]
        )
        self.layernorm_1 = layers.LayerNormalization()
        self.layernorm_2 = layers.LayerNormalization()

    def call(self, inputs, mask=None):
        if mask is not None:
            mask = mask[:, tf.newaxis, :]

        attention_output = self.attention(inputs, inputs, attention_mask=mask)
        proj_input = self.layernorm_1(inputs + attention_output)
        proj_output = self.dense_proj(proj_input)
        return self.layernorm_2(proj_input + proj_output)

def get_compiled_model():
    sequence_length = MAX_SEQ_LENGTH
    embed_dim = NUM_FEATURES
    dense_dim = 4
    num_heads = 1
    classes = 2

    inputs = keras.Input(shape=(None, None))
    x = PositionalEmbedding(
        sequence_length, embed_dim, name="frame_position_embedding"
    )(inputs)
    x = TransformerEncoder(embed_dim, dense_dim, num_heads, name="transformer_layer")(x)
    x = layers.GlobalMaxPooling1D()(x)
    x = layers.Dropout(0.5)(x)
    outputs = layers.Dense(classes, activation="softmax")(x)
    model = keras.Model(inputs, outputs)

    model.compile(
        optimizer="adam", loss="sparse_categorical_crossentropy", metrics=["accuracy"]
    )
    return model


def run_experiment():
    filepath = "/tmp/video_classifier"
    checkpoint = keras.callbacks.ModelCheckpoint(
        filepath, save_weights_only=True, save_best_only=True, verbose=1
    )

    model = get_compiled_model()
    history = model.fit(
        train_data[0],
        train_labels,
        validation_split=0.01,
        epochs=10,
        callbacks=[checkpoint],
    )

    model.load_weights(filepath)
    _, accuracy = model.evaluate(test_data[0], test_labels)
    print(f"Test accuracy: {round(accuracy * 100, 2)}%")

    return model

# %%
trained_model = run_experiment()
# Out:
# Epoch 1/10
# 26/27 [===========================>..] - ETA: 0s - loss: 3.2386 - accuracy: 0.6082
# Epoch 1: val_loss improved from inf to 1.47012, saving model to /tmp/video_classifier
# 27/27 [==============================] - 8s 89ms/step - loss: 3.1598 - accuracy: 0.6128 - val_loss: 1.4701 - val_accuracy: 0.0000e+00
# Epoch 2/10
# 25/27 [==========================>...] - ETA: 0s - loss: 0.5794 - accuracy: 0.7812
# Epoch 2: val_loss did not improve from 1.47012
# 27/27 [==============================] - 1s 21ms/step - loss: 0.5614 - accuracy: 0.7872 - val_loss: 1.8245 - val_accuracy: 0.0000e+00
# Epoch 3/10
# 25/27 [==========================>...] - ETA: 0s - loss: 0.3711 - accuracy: 0.8462
# Epoch 3: val_loss did not improve from 1.47012
# 27/27 [==============================] - 1s 22ms/step - loss: 0.3855 - accuracy: 0.8442 - val_loss: 1.7124 - val_accuracy: 0.0000e+00
# Epoch 4/10
# 25/27 [==========================>...] - ETA: 0s - loss: 0.2610 - accuracy: 0.8975
# ...
